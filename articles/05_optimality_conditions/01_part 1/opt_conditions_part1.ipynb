# %% [markdown]
# ---
# title: "Optimality conditions - Part 1"
# subtitle: "The fundamentals of mathematical optimization"
# author: "Röx"
# date: "08 January 2026"
# # image: "figures/newton.jpg"
# format:
#   html:
#     theme: journal
#     toc: true
#     toc-title: Contents
#     toc-depth: 3
#     smooth-scroll: true
#     number-sections: true
#     fig-caption: true
# engine: jupyter
# draft: true
# ---
