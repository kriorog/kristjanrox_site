# %% [markdown]
# ---
# title: "Does zero probability imply impossibility?"
# subtitle: "What does it mean to say that an event has zero probability?"
# author: "Röx"
# date: "04 January 2026"
# image: "figures/newton.jpg"
# format:
#   html:
#     theme: journal
#     toc: true
#     toc-title: Contents
#     toc-depth: 3
#     smooth-scroll: true
#     numbered-sections: true
#     fig-caption: true
# engine: jupyter
# draft: true
# ---
